# %%
# %%capture _ 
# ^ this just silences warnings
import torch
import mlflow
import hiddenlayer as HL

from model.collectdata_mdsA import collect_data
from model.alt_loss_A import Loss
from model.training import trainNet, select_gpu

from model.training import trainNet
from model.utilities import load_full_state, count_parameters, Params, save_to_mlflow
from model.autoencoder_models import UNet
from model.autoencoder_exp import NestNet

# %%
args = Params(
    batch_size=64,
    device = select_gpu(0),
    epochs=20,
    lr=4e-4,
    experiment_name='UNet+', 
    asymmetry_parameter=2.5
)
# Out:
# 1 available GPUs (initially using device 0):
#   0 GeForce RTX 2080 Ti

# %%
train_loader = collect_data(
    '/share/lazy/sokoloff/ML-data_A/Aug14_80K_train.h5',
#     '/share/lazy/sokoloff/ML-data_AA/Oct03_80K_train.h5',
#     '/share/lazy/sokoloff/ML-data_AA/Oct03_40K_train.h5',
#     '/share/lazy/will/ML_mdsA/June30_2020_80k_1.h5',
#     '/share/lazy/will/ML_mdsA/June30_2020_80k_3.h5',
#     '/share/lazy/will/ML_mdsA/June30_2020_80k_4.h5',
#     '/share/lazy/will/ML_mdsA/June30_2020_80k_5.h5',
#     '/share/lazy/will/ML_mdsA/June30_2020_80k_6.h5',
#     '/share/lazy/will/ML_mdsA/June30_2020_80k_7.h5',
#     '/share/lazy/will/ML_mdsA/June30_2020_80k_8.h5',
#     '/share/lazy/will/ML_mdsA/June30_2020_80k_9.h5',
    batch_size=args['batch_size'],
    masking=True,
    shuffle=False,
    load_XandXsq=False,
#     device = args['device'], 
    load_xy=False
)

val_loader = collect_data(
    '/share/lazy/sokoloff/ML-data_AA/Oct03_20K_val.h5',
    batch_size=args['batch_size'],
    slice=slice(256 * 39),
    masking=True, 
    shuffle=False,
    load_XandXsq=False,
    load_xy=False)
# Out:
# Loading data...
# Loaded /share/lazy/sokoloff/ML-data_A/Aug14_80K_train.h5 in 9.869 s
# Constructing 80000 event dataset took 0.2684 s
# Loading data...
# Loaded /share/lazy/sokoloff/ML-data_AA/Oct03_20K_val.h5 in 2.521 s
# Constructing 9984 event dataset took 0.04894 s

# %%
mlflow.tracking.set_tracking_uri('file:/share/lazy/pv-finder_model_repo')
mlflow.set_experiment(args['experiment_name'])
# Out:
# WARNING:root:Malformed experiment 'ML'. Detailed error Yaml file '/share/lazy/pv-finder_model_repo/ML/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/apps/miniconda3/envs/june2020-gpu/lib/python3.7/site-packages/mlflow/store/tracking/file_store.py", line 197, in list_experiments
#     experiment = self._get_experiment(exp_id, view_type)
#   File "/apps/miniconda3/envs/june2020-gpu/lib/python3.7/site-packages/mlflow/store/tracking/file_store.py", line 260, in _get_experiment
#     meta = read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#   File "/apps/miniconda3/envs/june2020-gpu/lib/python3.7/site-packages/mlflow/utils/file_utils.py", line 167, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/share/lazy/pv-finder_model_repo/ML/meta.yaml' does not exist.

# %%
model = NestNet(in_channels=16, n_classes=1).to(args['device'])
optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
loss = Loss(epsilon=1e-5,coefficient=2.5)

print(model.state_dict)
# Out:
# <bound method Module.state_dict of NestNet(
#   (x_00): StandardUnit(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (1): Dropout2d(p=0.5, inplace=False)
#       (2): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (3): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (x_01): StandardUnit(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (1): Dropout2d(p=0.5, inplace=False)
#       (2): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (3): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (x_02): StandardUnit(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (1): Dropout2d(p=0.5, inplace=False)
#       (2): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (3): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (x_03): StandardUnit(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (1): Dropout2d(p=0.5, inplace=False)
#       (2): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (3): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (x_04): StandardUnit(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (1): Dropout2d(p=0.5, inplace=False)
#       (2): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (3): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (up_10_to_01): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#   (up_11_to_02): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#   (up_12_to_03): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#   (up_13_to_04): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#   (x_10): StandardUnit(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (1): Dropout2d(p=0.5, inplace=False)
#       (2): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (3): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (x_11): StandardUnit(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (1): Dropout2d(p=0.5, inplace=False)
#       (2): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (3): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (x_12): StandardUnit(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (1): Dropout2d(p=0.5, inplace=False)
#       (2): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (3): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (x_13): StandardUnit(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (1): Dropout2d(p=0.5, inplace=False)
#       (2): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (3): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (up_20_to_11): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   (up_21_to_12): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   (up_22_to_13): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   (x_20): StandardUnit(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (1): Dropout2d(p=0.5, inplace=False)
#       (2): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (3): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (x_21): StandardUnit(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (1): Dropout2d(p=0.5, inplace=False)
#       (2): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (3): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (x_22): StandardUnit(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (1): Dropout2d(p=0.5, inplace=False)
#       (2): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (3): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (up_30_to_21): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#   (up_31_to_22): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#   (x_30): StandardUnit(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (1): Dropout2d(p=0.5, inplace=False)
#       (2): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (3): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (x_31): StandardUnit(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (1): Dropout2d(p=0.5, inplace=False)
#       (2): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (3): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (up_40_to_31): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#   (x_40): StandardUnit(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (1): Dropout2d(p=0.5, inplace=False)
#       (2): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((1, 1, 1, 1))
#           (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#         )
#       )
#       (3): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (final_1x1_x01): Final1x1ConvLayer(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((0, 0, 0, 0))
#           (1): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (1): Sigmoid()
#     )
#   )
#   (final_1x1_x02): Final1x1ConvLayer(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((0, 0, 0, 0))
#           (1): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (1): Sigmoid()
#     )
#   )
#   (final_1x1_x03): Final1x1ConvLayer(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((0, 0, 0, 0))
#           (1): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (1): Sigmoid()
#     )
#   )
#   (final_1x1_x04): Final1x1ConvLayer(
#     (layer): Sequential(
#       (0): ConvSamePad(
#         (layer): Sequential(
#           (0): ReflectionPad2d((0, 0, 0, 0))
#           (1): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (1): Sigmoid()
#     )
#   )
# )>

# %%
# load_full_state(model, optimizer, '/share/lazy/pv-finder_model_repo/0/a868d4b8ec0642b39a7156f3dd894dfb/artifacts/run_stats.pyt', freeze_weights=False)

run_name = 'u-net+'

# tune kernel based on gpu
#torch.backends.cudnn.benchmark=True
train_iter = enumerate(trainNet(model, optimizer, loss, train_loader, val_loader, args['epochs'], notebook=True))
with mlflow.start_run(run_name = run_name) as run:
    for i, result in train_iter:
        save_to_mlflow({
            'Metric: Training loss':result.cost,
            'Metric: Validation loss':result.val,
            'Metric: Efficiency':result.eff_val.eff_rate,
            'Metric: False positive rate':result.eff_val.fp_rate,
        }, step=i)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-34b468c46587> in <module>
#       7 train_iter = enumerate(trainNet(model, optimizer, loss, train_loader, val_loader, args['epochs'], notebook=True))
#       8 with mlflow.start_run(run_name = run_name) as run:
# ----> 9     for i, result in train_iter:
#      10         save_to_mlflow({
#      11             'Metric: Training loss':result.cost,
#
# ~/pv-finder_fork/pv-finder/notebooks/model/training.py in trainNet(model, optimizer, loss, train_loader, val_loader, n_epochs, notebook, epoch_start)
#      82
#      83     # Get the current device
# ---> 84     device = get_device_from_model(model)
#      85
#      86     print(f"Number of batches: train = {len(train_loader)}, val = {len(val_loader)}")
#
# ~/pv-finder_fork/pv-finder/notebooks/model/utilities.py in get_device_from_model(model)
#     163         return model.weight.device
#     164     else:
# --> 165         return get_device_from_model(list(model.children())[0])
#
# ~/pv-finder_fork/pv-finder/notebooks/model/utilities.py in get_device_from_model(model)
#     163         return model.weight.device
#     164     else:
# --> 165         return get_device_from_model(list(model.children())[0])
#
# ~/pv-finder_fork/pv-finder/notebooks/model/utilities.py in get_device_from_model(model)
#     163         return model.weight.device
#     164     else:
# --> 165         return get_device_from_model(list(model.children())[0])
#
# ~/pv-finder_fork/pv-finder/notebooks/model/utilities.py in get_device_from_model(model)
#     163         return model.weight.device
#     164     else:
# --> 165         return get_device_from_model(list(model.children())[0])
#
# ~/pv-finder_fork/pv-finder/notebooks/model/utilities.py in get_device_from_model(model)
#     163         return model.weight.device
#     164     else:
# --> 165         return get_device_from_model(list(model.children())[0])
#
# ~/pv-finder_fork/pv-finder/notebooks/model/utilities.py in get_device_from_model(model)
#     163         return model.weight.device
#     164     else:
# --> 165         return get_device_from_model(list(model.children())[0])
#
# IndexError: list index out of range
